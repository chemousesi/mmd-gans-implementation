# %% [markdown]
# # MMD-DCGAN with feature training

# %% [markdown]
# ## 0.Imports and utils

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision.datasets import MNIST
from torchvision import transforms
import torchvision.utils as vutils
import torch.utils.data as data

import matplotlib.pyplot as plt
import os
import numpy as np
import time

import torchvision

# %%
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
print("Device is", device)
# !nvidia-smi

# Displaying function
def imshow(img,size=None):
    img = img*0.5 + 0.5     # unnormalize
    if size is not None:
        img = transforms.Resize(size=size, interpolation=transforms.InterpolationMode.NEAREST, antialias=True)(img)
    pil_img = torchvision.transforms.functional.to_pil_image(img)
    display(pil_img)
    # print("Image size (h x w): ",  pil_img.height, "x", pil_img.width)
    return None
# Out:
# Device is cuda:2

# %%
batch_size=128
transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))])
train_set = MNIST(os.getcwd(), train=True, transform=transform, download=True)
train_loader = data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=2, drop_last=True)

# %%
real,_ = next(iter(train_loader))
print(real.shape)

pil_img = imshow(torchvision.utils.make_grid(real.to(device),nrow=16))
# Out:
# torch.Size([128, 1, 28, 28])
# <PIL.Image.Image image mode=RGB size=482x242>

# %%
# Size  of generator input
nz = 100

# Size of feature maps in generator and discriminator
ngf, ndf = 64, 64

class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(in_channels = nz, out_channels = ngf * 8, kernel_size = 4, stride = 1, padding = 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(in_channels = ngf * 8, out_channels = ngf * 4, kernel_size = 4, stride = 2, padding = 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d(in_channels = ngf * 4, out_channels = ngf * 2, kernel_size = 4, stride = 2, padding = 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d(in_channels = ngf * 2, out_channels = ngf, kernel_size = 4, stride = 2, padding = 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d(in_channels = ngf, out_channels = 1, kernel_size=1, stride=1, padding=2, bias=False),
            nn.Tanh()
            # output size. 1 x 28 x 28
        )

    def forward(self, input):
        return self.main(input)


class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            # input is 1 x 28 x 28
            nn.Conv2d(in_channels = 1, out_channels = ndf, kernel_size = 4, stride = 2, padding = 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 15 x 15
            nn.Conv2d(in_channels = ndf, out_channels= ndf * 2, kernel_size = 4, stride = 2, padding = 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*2) x 8 x 8
            nn.Conv2d(in_channels = ndf * 2, out_channels = ndf * 4, kernel_size = 4, stride = 2, padding = 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*4) x 5 x 5
            nn.Conv2d(in_channels = ndf * 4, out_channels = 1, kernel_size = 4, stride = 2, padding = 1, bias=False)
        )

    def forward(self, input):
        return self.main(input).view(-1, 1).squeeze(1)

# check sizes:
# import torchsummary

# # Create some generator and discriminator
# netG = Generator().to(device)
# netD = Discriminator().to(device)

# torchsummary.summary(netG, input_size=(nz,1,1))
# torchsummary.summary(netD, input_size=(1,28,28))

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Define the number of filters for the discriminator
ndf = 64

class DiscriminatorFeatureExtractor(nn.Module):
    def __init__(self):
        super(DiscriminatorFeatureExtractor, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=ndf, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size: (ndf) x 14 x 14
            nn.Conv2d(in_channels=ndf, out_channels=ndf * 2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size: (ndf*2) x 7 x 7
            nn.Conv2d(in_channels=ndf * 2, out_channels=ndf * 4, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size: (ndf*4) x 4 x 4
        )

    def forward(self, x):
        features = self.main(x)
        features = features.view(features.size(0), -1)  # Flatten to a feature vector
        return features

# Example of using the modified discriminator as a feature extractor
feature_extractor = DiscriminatorFeatureExtractor().to(device)
sample_input = torch.randn(1, 1, 28, 28).to(device)  # Batch size of 1, 1 channel, 28x28 image
features = feature_extractor(sample_input)

print(features.shape)  # Output feature vector shape
# Out:
# torch.Size([1, 2304])

# %%
# function to display samples of the generator
def show(G,z=None,batch_size=128,nz=100,device = device):
  # provide random latent code as option to see evolution
  with torch.no_grad():
    if z==None:
      z = torch.randn(batch_size,nz,1,1).to(device)
    genimages = G(z)
    pil_img = imshow(torchvision.utils.make_grid(genimages.to(device),nrow=16))
    return(pil_img)

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# Create the generator and discriminator
G = Generator().to(device)
D = Discriminator().to(device)

# Apply the weights_init function to randomly initialize all weights to mean=0, stdev=0.02.
G.apply(weights_init);
D.apply(weights_init);

show(G);
# Out:
# <PIL.Image.Image image mode=RGB size=482x242>

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 32, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Flatten()
        )

    def forward(self, img):
        features = self.model(img)
        return features

# %% [markdown]
# ## MMD GAN

# %%
def MMD(x, y):
    """Emprical maximum mean discrepancy. The lower the result, the more evidence that distributions are the same.

    Args:
        x: first sample, distribution P
        y: second sample, distribution Q
        kernel: kernel type such as "multiscale" or "rbf"
    """
    x = x.view(x.size(0), -1)  # [batch_size, features]
    y = y.view(y.size(0), -1)  # [batch_size, features]

    xx, yy, zz = torch.mm(x, x.t()), torch.mm(y, y.t()), torch.mm(x, y.t())
    rx = (xx.diag().unsqueeze(0).expand_as(xx))
    ry = (yy.diag().unsqueeze(0).expand_as(yy))

    dxx = rx.t() + rx - 2. * xx # Used for A in (1)
    dyy = ry.t() + ry - 2. * yy # Used for B in (1)
    """
    print(rx.t().shape)
    print(ry.shape)
    print(zz.shape)
    """
    dxy = rx.t() + ry - 2. * zz # Used for C in (1)

    XX, YY, XY = (torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device))


    #rbf kernel
    #bandwidth_range = [10, 15, 20, 50]
    bandwidth_range = [2, 5, 10, 20, 40, 80]
    for a in bandwidth_range:
      XX += torch.exp(-0.5*dxx/a)
      YY += torch.exp(-0.5*dyy/a)
      XY += torch.exp(-0.5*dxy/a)

    return torch.mean(XX + YY - 2. * XY)

# %% [markdown]
# ## Helper Functions
# ### gradient penalty

# %%
def gradient_penalty(D, x, y):
    b = x.shape[0]
    n = y.shape[0]
    # shrink vectors if they are too large
    if n > b:
        y = y[0:b, :, :, :]
        n = b
    else:
        x = x[0:n, :, :, :]
        b = n
    # compute interpolated points
    alpha = torch.rand((b, 1, 1, 1), device=device)
    interp = alpha * y + (1 - alpha) * x
    interp.requires_grad_()

    # Calculate probability of interpolated examples
    Di = D(interp).view(-1)

    # Calculate gradients of probabilities with respect to examples
    gradout = torch.ones(Di.size()).to(device)
    gradients = torch.autograd.grad(outputs=Di, inputs=interp, grad_outputs=gradout,
                                    create_graph=True, retain_graph=True)[0]

    # Derivatives of the gradient close to 0 can cause problems because of
    # the square root, so manually calculate norm and add epsilon
    gradients = gradients.view(b, -1)
    gradients_norm = torch.sqrt(torch.sum(gradients ** 2, dim=1) + 1e-12)  # Add epsilon to avoid numerical instability

    # Return gradient penalty
    return ((gradients_norm - 1) ** 2).mean()

# %% [markdown]
# ### Gaussian kernel

# %%
# Gaussian kernel function
# todo : check if the params are good and if it is possible to find better 
def gaussian_kernel(x, y, sigma=1.0):
    beta = 1.0 / (2.0 * sigma ** 2)
    dist = torch.cdist(x, y, p=2)
    return torch.exp(-beta * dist)

# %% [markdown]
# ## Home Made MMD Loss

# %%
# MMD loss function
def mmd_loss(real_features, fake_features, kernel):
    mmd = torch.mean(kernel(real_features, real_features)) \
        + torch.mean(kernel(fake_features, fake_features)) \
        - 2 * torch.mean(kernel(real_features, fake_features))
    return mmd

# %% [markdown]
# ## TRAIN MMD-DCGAN

# %% [markdown]
# sur gpu

# %%
# MODIFIED MMD GAN
torch.manual_seed(1)  # initialize random seed for reproducibility
from tqdm import tqdm

log_every = 300
gpw = 0.05

G = Generator().to(device)
D = Discriminator().to(device)
#feature_extractor = FeatureExtractor().to(device)
G.apply(weights_init);
D.apply(weights_init);

# Example of using the modified discriminator as a feature extractor
feature_extractor = DiscriminatorFeatureExtractor().to(device)
sample_input = torch.randn(1, 1, 28, 28).to(device)  # Batch size of 1, 1 channel, 28x28 image
features = feature_extractor(sample_input)

feature_extractor.apply(weights_init);

optimD = optim.Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimG = optim.Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimFE = optim.Adam(feature_extractor.parameters(), lr=0.0002, betas=(0.5, 0.999))

zviz = torch.randn(batch_size,nz,1,1).to(device)

# %%
gpw = 0.1
num_epochs = 10


losses = [] # to keep track of the losses 
t0 = time.time()
for epoch in range(num_epochs):
    # For each batch in the train_loader
    for i, batch in enumerate(tqdm(train_loader, 0), 0):

        real = batch[0].to(device)
        
        optimG.zero_grad()
        feature_extractor.zero_grad()

        fake = G(torch.randn(batch_size, nz, 1, 1, device=device))
        faked = fake.detach()
        output = D(fake)
       
        gp = gradient_penalty(D,real,fake)
       
        # if i > 20 and i % 500 == 0:
        #         optimFE.step()

        # joint to have common batch-norm transform
        # outputs = D(torch.cat([real, fake], dim=0))
        # output_real = outputs[:real.size(0)]
        # output_fake = outputs[real.size(0):]

        # MMD = torch.norm(output_fake.mean(dim=0) - output_real.mean(dim=0))
    
        output_real = feature_extractor(real)
        output_fake = feature_extractor(fake)
        
        loss = MMD(output_real, output_fake)

        Gloss = torch.mean(loss) #+ gpw*gp
        #Gloss = loss
        Gloss.backward(retain_graph=True)
        #MMD.backward(retain_graph=True)

        #optimD.step()
        #feature_extractor.zero_grad()
        optimFE.step()
        optimG.step()
        #optimD.step()
        

        if i % log_every == 0:
            print('[%d/%d][%d/%d][%.4f s]\tLoss_G: %.4f\t'
                  % (epoch+1, num_epochs, i, len(train_loader), time.time()-t0, Gloss.item()))
            losses.append(Gloss.item())
    
    
print('Total learning time = ',time.time()-t0)
# Out:
#   1%|          | 3/468 [00:05<10:16,  1.33s/it]
# [1/10][0/468][4.8693 s]	Loss_G: 0.0939
#  65%|██████▍   | 304/468 [00:24<00:10, 15.53it/s]
# [1/10][300/468][24.6626 s]	Loss_G: 0.0938
# 100%|██████████| 468/468 [00:35<00:00, 13.16it/s]
#   0%|          | 2/468 [00:05<16:44,  2.16s/it]
# [2/10][0/468][40.6567 s]	Loss_G: 0.0938
#  65%|██████▍   | 302/468 [00:24<00:10, 16.53it/s]
# [2/10][300/468][59.6745 s]	Loss_G: 0.0938
# 100%|██████████| 468/468 [00:34<00:00, 13.38it/s]
#   1%|          | 3/468 [00:05<11:33,  1.49s/it]
# [3/10][0/468][76.0691 s]	Loss_G: 0.0938
#  65%|██████▍   | 303/468 [00:24<00:10, 16.08it/s]
# [3/10][300/468][94.8555 s]	Loss_G: 0.0937
# 100%|██████████| 468/468 [00:35<00:00, 13.26it/s]
#   0%|          | 2/468 [00:03<11:02,  1.42s/it]
# [4/10][0/468][109.1569 s]	Loss_G: 0.0937
#  65%|██████▍   | 304/468 [00:23<00:09, 17.50it/s]
# [4/10][300/468][128.7552 s]	Loss_G: 0.0938
# 100%|██████████| 468/468 [00:34<00:00, 13.60it/s]
#   1%|          | 3/468 [00:04<09:43,  1.25s/it]
# [5/10][0/468][144.8623 s]	Loss_G: 0.0938
#  65%|██████▍   | 304/468 [00:24<00:11, 14.31it/s]
# [5/10][300/468][164.1579 s]	Loss_G: 0.0937
# 100%|██████████| 468/468 [00:34<00:00, 13.37it/s]
#   0%|          | 2/468 [00:04<16:06,  2.07s/it]
# [6/10][0/468][180.0584 s]	Loss_G: 0.0938
#  65%|██████▍   | 303/468 [00:24<00:11, 14.95it/s]
# [6/10][300/468][200.0787 s]	Loss_G: 0.0937
# 100%|██████████| 468/468 [00:36<00:00, 12.96it/s]
#   1%|          | 3/468 [00:04<09:55,  1.28s/it]
# [7/10][0/468][216.1486 s]	Loss_G: 0.0937
#  65%|██████▍   | 304/468 [00:23<00:09, 16.81it/s]
# [7/10][300/468][234.7644 s]	Loss_G: 0.0937
# 100%|██████████| 468/468 [00:34<00:00, 13.57it/s]
#   0%|          | 2/468 [00:04<14:51,  1.91s/it]
# [8/10][0/468][250.3576 s]	Loss_G: 0.0937
#  65%|██████▍   | 304/468 [00:23<00:11, 14.78it/s]
# [8/10][300/468][269.6554 s]	Loss_G: 0.0938
# 100%|██████████| 468/468 [00:35<00:00, 13.22it/s]
#   1%|          | 3/468 [00:05<10:32,  1.36s/it]
# [9/10][0/468][286.2651 s]	Loss_G: 0.0938
#  65%|██████▍   | 303/468 [00:23<00:10, 16.15it/s]
# [9/10][300/468][304.9492 s]	Loss_G: 0.0938
# 100%|██████████| 468/468 [00:35<00:00, 13.07it/s]
#   1%|          | 3/468 [00:04<09:47,  1.26s/it]
# [10/10][0/468][321.6613 s]	Loss_G: 0.0937
#  65%|██████▍   | 304/468 [00:24<00:10, 15.09it/s]
# [10/10][300/468][341.1536 s]	Loss_G: 0.0937
# 100%|██████████| 468/468 [00:35<00:00, 13.30it/s]
# Total learning time =  352.26327252388

# %%
show(G,zviz,device = device)
plt.plot(losses)
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=482x242>

# %% [markdown]
# 35 epochs \
# ![image.png](attachment:image.png)
#
# 45 epochs\
# ![image-2.png](attachment:image-2.png)
#
# 50 epochs\
# ![image-3.png](attachment:image-3.png)
#
# 5 epochs with GP\
# ![image-4.png](attachment:image-4.png)
# 6
# ![image-5.png](attachment:image-5.png)
#
# 15 epochs with gradient penalty 0.1\
#
# ![image-6.png](attachment:image-6.png)\
#
#
# 948.7362341880798\
#
#
# GP 0.05  \
#
# ![image-7.png](attachment:image-7.png)\
# Numbers are way cleaner with the gradient penalty \
#
# ![image-8.png](attachment:image-8.png)\
#
#
# 50 epochs with gradient penalty 0.07\
# ![image-9.png](attachment:image-9.png)\
#
# 20 epochs with mmd home made penalty 0.05\
# ![image-11.png](attachment:image-11.png)\
# ![image-12.png](attachment:image-12.png)\
#
# \
# 10 epochs with feature extractor \ mmdloss
#
#
# 10 epochs with Feature extractor training \
# ![image-10.png](attachment:image-10.png)\
#
#
#
# Inspired by the work of a [paper](https://arxiv.org/abs/1705.08584) when training the feature extractore once every 500 iterations it takes 20 min on the school machines **Tesla V100S-PCIE-32GB** and it gives this : \
#
#
#
# with this loss \

# %%
torch.save(G.state_dict(), 'model_weights/final_gradient_penalty.pth')
torch.save(D.state_dict(), 'model_weights/final.pth')
torch.save(feature_extractor.state_dict(), 'model_weights/final.pth')

# %% [markdown]
# ## trying to train the descrimnator from time to time

# %%
gpw = 0.05
num_epochs = 10
#sorry for the bad code, I am in a hurry
losses = []
t0 = time.time()
for epoch in range(num_epochs):
    # For each batch in the train_loader
    for i, batch in enumerate(tqdm(train_loader, 0), 0):

        real = batch[0].to(device)
        
        optimG.zero_grad()
        feature_extractor.zero_grad()

        fake = G(torch.randn(batch_size, nz, 1, 1, device=device))
        faked = fake.detach()
        output = D(fake)
       
        gp = gradient_penalty(D,real,fake)
       
        # joint to have common batch-norm transform
        # outputs = D(torch.cat([real, fake], dim=0))
        # output_real = outputs[:real.size(0)]
        # output_fake = outputs[real.size(0):]

        # MMD = torch.norm(output_fake.mean(dim=0) - output_real.mean(dim=0))
    
        output_real = feature_extractor(real)
        output_fake = feature_extractor(fake)
        
        #loss = MMD(output_real.view(real.size(0), -1), output_fake.view(output.size(0), -1))        #Gloss = torch.mean(MMD(real,fake)) + gpw*gp
        loss = mmd_loss(output_real, output_fake, gaussian_kernel)
        Gloss = loss + gpw*gp
        #Gloss = loss
        Gloss.backward(retain_graph=True)
        #MMD.backward(retain_graph=True)

        #optimD.step()
        optimG.step()
        

        if i % log_every == 0:
            print('[%d/%d][%d/%d][%.4f s]\tLoss_G: %.4f\t'
                  % (epoch+1, num_epochs, i, len(train_loader), time.time()-t0, Gloss.item()))
            losses.append(Gloss.item())
    
    
print('Total learning time = ',time.time()-t0)

# %% [markdown]
# ## Gradien penalty

# %%
def gradient_penalty(D, x, y):
    b = x.shape[0]
    n = y.shape[0]
    # shrink vectors if they are too large
    if n > b:
        y = y[0:b, :, :, :]
        n = b
    else:
        x = x[0:n, :, :, :]
        b = n
    # compute interpolated points
    alpha = torch.rand((b, 1, 1, 1), device=device)
    interp = alpha * y + (1 - alpha) * x
    interp.requires_grad_()

    # Calculate probability of interpolated examples
    Di = D(interp).view(-1)

    # Calculate gradients of probabilities with respect to examples
    gradout = torch.ones(Di.size()).to(device)
    gradients = torch.autograd.grad(outputs=Di, inputs=interp, grad_outputs=gradout,
                                    create_graph=True, retain_graph=True)[0]

    # Derivatives of the gradient close to 0 can cause problems because of
    # the square root, so manually calculate norm and add epsilon
    gradients = gradients.view(b, -1)
    gradients_norm = torch.sqrt(torch.sum(gradients ** 2, dim=1) + 1e-12)  # Add epsilon to avoid numerical instability

    # Return gradient penalty
    return ((gradients_norm - 1) ** 2).mean()

# %% [markdown]
# TODO : Trying to back on the mmd

# %%
num_epochs = 10

t0 = time.time()
for epoch in range(num_epochs):
    # For each batch in the train_loader
    for i, batch in enumerate(tqdm(train_loader, 0), 0):

        ############################
        # Batchs of real and fake images
        real = batch[0].to(device)
        fake = G(torch.randn(batch_size, nz, 1, 1, device=device))
        faked = fake.detach()

        ############################
        # Update G network
        ### ... ###
        optimG.zero_grad()

        fake = G(torch.randn(batch_size, nz, 1, 1, device=device))
        output = D(fake)

        Gloss = torch.mean(MMD(fake,real))
        Gloss.backward()
        optimG.step()

        ############################
        # Display training stats and visualize
        if i % log_every == 0:
            print('[%d/%d][%d/%d][%.4f s]\tLoss_G: %.4f\t'
                  % (epoch+1, num_epochs, i, len(train_loader), time.time()-t0, Gloss.item()))
        
        #show(G,zviz,device = device)

print('Total learning time = ',time.time()-t0)

# %%
# Save final generator in a variable for later use
wgan = Generator()
wgan.load_state_dict(G.state_dict())
